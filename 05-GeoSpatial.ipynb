# %%
# !pip3 install shapely
# Out:
# Collecting shapely
#   Downloading Shapely-1.6.1-cp35-cp35m-macosx_10_6_intel.whl (2.6MB)
#     100% |████████████████████████████████| 2.6MB 43kB/s ta 0:00:017
# Installing collected packages: shapely
# Successfully installed shapely-1.6.1

# %% [markdown]
# # Geospatial analysis
#
#
# - 14 million trip in NYC
#
#
# ## Goal Compute the utilization

# %%
from pyspark import SparkContext
from pyspark import SparkConf
from pyspark.sql import SparkSession
from pyspark.rdd import portable_hash
from pyspark.statcounter import StatCounter
import shapely


import os
import json

from datetime import datetime
from operator import itemgetter
#from itertools import chain, imap
from shapely.geometry import shape, Point

from matplotlib import pyplot as plt

spark = SparkSession.builder.appName("Taxi")\
        .config("spark.driver.memory", "6g")\
        .config("spark.driver.cores", "8")\
        .getOrCreate()
sc=spark.sparkContext

# %%
from  pprint import pprint
def title(s):
    pprint("---- %s -----" %s)    
    
def see(s, v):
    pprint("---- %s -----" %s)
    pprint(v)

# %% [markdown]
# # 1. Sample the Data
# - Save the sample to a file, because the sampling itself is time-consuming

# %%
taxiRawAll = sc.textFile("../sample.csv")
header = sc.parallelize(taxiRawAll.take(1))
taxiRaw = taxiRawAll.sample(withReplacement=False, fraction=0.0001 ,seed=17)
taxiRaw.coalesce(1) #Makes 1 file as an output, since it reduced the # of partitions to 1
#header.union(taxiRaw).saveAsTextFile("../data/ch08-geospatial/trip_data_sample.csv")
# Out:
# CoalescedRDD[18] at coalesce at NativeMethodAccessorImpl.java:-2

# %% [markdown]
# # 2. Read the sample Data
# - Save the sample to a file, because the sampling itself is time-consuming

# %%
#read the sample
taxiRaw = sc.textFile("../sample.csv")

# %%
taxiRaw.take(3)
# Out:
# ['medallion,hack_license,vendor_id,rate_code,store_and_fwd_flag,pickup_datetime,dropoff_datetime,passenger_count,trip_time_in_secs,trip_distance,pickup_longitude,pickup_latitude,dropoff_longitude,dropoff_latitude',
#  '89D227B655E5C82AECF13C3F540D4CF4,BA96DE419E711691B9445D6A6307C170,CMT,1,N,2013-01-01 15:11:48,2013-01-01 15:18:10,4,382,1.00,-73.978165,40.757977,-73.989838,40.751171',
#  '0BD7C8F5BA12B88E0B67BED28BEA73D8,9FD8F69F0804BDB5549F40E9DA1BE472,CMT,1,N,2013-01-06 00:18:35,2013-01-06 00:22:54,1,259,1.50,-74.006683,40.731781,-73.994499,40.75066']

# %%
df = spark.read.csv("../sample.csv", header=True)
taxi = df.toPandas()
# df.select("hack_license", "pickup_datetime", "pickup_longitude", "pickup_latitude", "dropoff_datetime", "dropoff_longitude", "dropoff_latitude").toPandas()
# from pyspark.sql import functions as F
# def toPoint(x,y):
#     return Point(float(x), float(x))
# df= df.withColumn("startT", F.to_timestamp(df.pickup_datetime))
# df= df.withColumn("endT", F.to_timestamp(df.dropoff_datetime))
# df.select("hack_license", "startT", "endT").limit(10).toPandas()

# %% [markdown]
# # 3. Parse the data handling Time and Geo  types
# - We are mainly intersted in each Trip's:
#     - Some Unique ID for the car (license)
#     - Pick-up location
#     - Pick-up time
#     - Drop-off location
#     - Drop-off time
# - We use python datetime class to store dates
# - We use shapely to store geo coordinates

# %%
def parse(fields):
    license = fields[1]
    pickupTime = datetime.strptime(fields[5], '%Y-%m-%d %H:%M:%S')
    dropoffTime = datetime.strptime(fields[6], '%Y-%m-%d %H:%M:%S')
    try:
        pickupLoc = Point(float(fields[10]), float(fields[11]))
        dropoffLoc = Point(float(fields[12]), float(fields[13]))
    except ValueError:
        pickupLoc = Point(0.0, 0.0)
        dropoffLoc= Point(0.0, 0.0)
    trip = {'pickupTime':pickupTime, 'dropoffTime':dropoffTime, 'pickupLoc':pickupLoc, 'dropoffLoc':dropoffLoc}
    return (license, trip)


taxiParsed = taxiRaw\
        .map(lambda line: line.split(','))\
        .filter(lambda fields: len(fields) == 14 and fields[0] != "medallion")\
        .map(parse)
taxiParsed.cache()

see("taxiParsed", taxiParsed.take(5))
# Out:
# '---- taxiParsed -----'
# [('BA96DE419E711691B9445D6A6307C170',
#   {'dropoffLoc': <shapely.geometry.point.Point object at 0x10e33d940>,
#    'dropoffTime': datetime.datetime(2013, 1, 1, 15, 18, 10),
#    'pickupLoc': <shapely.geometry.point.Point object at 0x10e33d9b0>,
#    'pickupTime': datetime.datetime(2013, 1, 1, 15, 11, 48)}),
#  ('9FD8F69F0804BDB5549F40E9DA1BE472',
#   {'dropoffLoc': <shapely.geometry.point.Point object at 0x10e33d5c0>,
#    'dropoffTime': datetime.datetime(2013, 1, 6, 0, 22, 54),
#    'pickupLoc': <shapely.geometry.point.Point object at 0x10e33da20>,
#    'pickupTime': datetime.datetime(2013, 1, 6, 0, 18, 35)}),
#  ('9FD8F69F0804BDB5549F40E9DA1BE472',
#   {'dropoffLoc': <shapely.geometry.point.Point object at 0x10e33da90>,
#    'dropoffTime': datetime.datetime(2013, 1, 5, 18, 54, 23),
#    'pickupLoc': <shapely.geometry.point.Point object at 0x10e33db00>,
#    'pickupTime': datetime.datetime(2013, 1, 5, 18, 49, 41)}),
#  ('51EE87E3205C985EF8431D850C786310',
#   {'dropoffLoc': <shapely.geometry.point.Point object at 0x10e33d978>,
#    'dropoffTime': datetime.datetime(2013, 1, 7, 23, 58, 20),
#    'pickupLoc': <shapely.geometry.point.Point object at 0x10e33dac8>,
#    'pickupTime': datetime.datetime(2013, 1, 7, 23, 54, 15)}),
#  ('51EE87E3205C985EF8431D850C786310',
#   {'dropoffLoc': <shapely.geometry.point.Point object at 0x10e33db70>,
#    'dropoffTime': datetime.datetime(2013, 1, 7, 23, 34, 24),
#    'pickupLoc': <shapely.geometry.point.Point object at 0x10e33dbe0>,
#    'pickupTime': datetime.datetime(2013, 1, 7, 23, 25, 3)})]

# %% [markdown]
# # 4. Process Time:
# ## 4.1 Explore the distribution of trip duration (hours)

# %%
def hours(trip):
    d= trip['dropoffTime'] - trip['pickupTime']
    return int( ((d.days)*24) + (d.seconds/3600))

hoursCount = taxiParsed.values().map(hours).countByValue().items()
sortedHoursCount = sorted(hoursCount, key=itemgetter(0), reverse=False)

for val in sortedHoursCount:
    print(val)
# Out:
# (0, 99946)
# (1, 50)
# (2, 3)

# %% [markdown]
# ## 4.2 Remove trips with -ve durations and longer than 3 hours

# %%
def goodHour(hrs):
    return 0 <= hrs and hrs < 3

taxiClean = taxiParsed.filter(lambda x: goodHour( hours(x[1]) )).cache()
taxiParsed.unpersist()

see("taxiClean", taxiClean.take(5))
# Out:
# '---- taxiClean -----'
# [('BA96DE419E711691B9445D6A6307C170',
#   {'dropoffLoc': <shapely.geometry.point.Point object at 0x10e33d9e8>,
#    'dropoffTime': datetime.datetime(2013, 1, 1, 15, 18, 10),
#    'pickupLoc': <shapely.geometry.point.Point object at 0x10e387a90>,
#    'pickupTime': datetime.datetime(2013, 1, 1, 15, 11, 48)}),
#  ('9FD8F69F0804BDB5549F40E9DA1BE472',
#   {'dropoffLoc': <shapely.geometry.point.Point object at 0x10e3876a0>,
#    'dropoffTime': datetime.datetime(2013, 1, 6, 0, 22, 54),
#    'pickupLoc': <shapely.geometry.point.Point object at 0x10e387b00>,
#    'pickupTime': datetime.datetime(2013, 1, 6, 0, 18, 35)}),
#  ('9FD8F69F0804BDB5549F40E9DA1BE472',
#   {'dropoffLoc': <shapely.geometry.point.Point object at 0x10e387b70>,
#    'dropoffTime': datetime.datetime(2013, 1, 5, 18, 54, 23),
#    'pickupLoc': <shapely.geometry.point.Point object at 0x10e387c18>,
#    'pickupTime': datetime.datetime(2013, 1, 5, 18, 49, 41)}),
#  ('51EE87E3205C985EF8431D850C786310',
#   {'dropoffLoc': <shapely.geometry.point.Point object at 0x10e387a58>,
#    'dropoffTime': datetime.datetime(2013, 1, 7, 23, 58, 20),
#    'pickupLoc': <shapely.geometry.point.Point object at 0x10e387ba8>,
#    'pickupTime': datetime.datetime(2013, 1, 7, 23, 54, 15)}),
#  ('51EE87E3205C985EF8431D850C786310',
#   {'dropoffLoc': <shapely.geometry.point.Point object at 0x10e387c88>,
#    'dropoffTime': datetime.datetime(2013, 1, 7, 23, 34, 24),
#    'pickupLoc': <shapely.geometry.point.Point object at 0x10e387cf8>,
#    'pickupTime': datetime.datetime(2013, 1, 7, 23, 25, 3)})]

# %% [markdown]
# # 5.Process Geo data
# ## 5.1 Geet a list of NY Zones (boroughs)

# %%
with open('../work/boroughs.geojson', 'r') as f:
        geo = json.load(f)
features = geo['features']
for f in features:
    f["shape"] = shape(f['geometry'])

see("features", features[:3])
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.

# %% [markdown]
# ## 5.2 Sort the zones by area and broadcast to executors

# %%
areaSortedFeatures = sorted(features, key=lambda f: (int(f['properties']["boroughCode"]), -f["shape"].area), reverse=False)
bFeatures = sc.broadcast(areaSortedFeatures)
see("areaSortedFeatures", areaSortedFeatures[:3])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-18-b90e7a54b500> in <module>()
# ----> 1 areaSortedFeatures = sorted(features, key=lambda f: (int(f['properties']["boroughCode"]), -f["shape"].area), reverse=False)
#       2 bFeatures = sc.broadcast(areaSortedFeatures)
#       3 see("areaSortedFeatures", areaSortedFeatures[:3])
#
# <ipython-input-18-b90e7a54b500> in <lambda>(f)
# ----> 1 areaSortedFeatures = sorted(features, key=lambda f: (int(f['properties']["boroughCode"]), -f["shape"].area), reverse=False)
#       2 bFeatures = sc.broadcast(areaSortedFeatures)
#       3 see("areaSortedFeatures", areaSortedFeatures[:3])
#
# KeyError: 'boroughCode'

# %% [markdown]
# ## 5.3 Convert long/lat to  zone

# %%
def borough(trip):
    for f in bFeatures.value:
        #contains checks if the 
        if f['shape'].contains(trip["dropoffLoc"]):
            return str(f['properties']["borough"])
    return None

boroughCount = taxiClean.values().map(borough).countByValue().items()

see("boroughCount", list(boroughCount))
# Out:
# '---- boroughCount -----'
# [('Manhattan', 88164),
#  ('Queens', 5475),
#  ('Brooklyn', 3595),
#  (None, 2357),
#  ('Bronx', 395),
#  ('Staten Island', 13)]

# %% [markdown]
# ## 5.4 Remove trips that started/ended in unknown zones

# %%
def hasZero(trip):
    zero = Point(0.0, 0.0)
    return (zero == trip["pickupLoc"] or zero == trip["dropoffLoc"])

taxiDone = taxiClean.filter(lambda x: not hasZero(x[1])).cache()

# %%
boroughCount = taxiDone.values().map(borough).countByValue().items()
see("boroughCount", list(boroughCount))
# Out:
# '---- boroughCount -----'
# [('Manhattan', 88139),
#  ('Queens', 5470),
#  ('Brooklyn', 3594),
#  (None, 456),
#  ('Bronx', 395),
#  ('Staten Island', 13)]

# %% [markdown]
# ## 6 Sessionize trips
# - Look at sorted list of trips for each driver
# - Once the difference between any 2 consecurtive trips is longer than 4 hours, we consider that a new session has started

# %%
epoch = datetime.utcfromtimestamp(0)

def getMillis(time):
    return (time - epoch).total_seconds() * 1000.0

def partitioner(n):
    def partitioner_(x):
        return portable_hash(x[0]) % n
    return partitioner_


def groupSorted(it, splitFunc):
    cur={'lic': None, 'trips': []}
    def mapper(x):
        lic = x[0][0]
        trip = x[1]
        if(lic != cur['lic'] or splitFunc(cur['trips'][-1], trip)):
            result = (cur['lic'], cur['trips'])
            cur['lic'] = lic
            cur['trips'] = [trip]
            if(len(result[1]) == 0):
                return None
            else:
                return result
        else:
            cur['trips'].append(trip)
            return None
    m = list(map(mapper, it))
    m.append((cur['lic'], cur['trips']))
    return filter(lambda f: f is not None, m)

def groupByKeyAndSortValues(rdd, secondaryKeyFunc, splitFunc):
    presess = rdd.map(lambda x: ((x[0], secondaryKeyFunc(x[1])), x[1]) )
    numPartitions = presess.getNumPartitions()
    return presess.repartitionAndSortWithinPartitions(partitionFunc=partitioner(numPartitions))\
        .mapPartitions(lambda partition: groupSorted(partition, splitFunc))
        
def split(t1, t2):
    d = t2['pickupTime'] - t1['pickupTime']
    return ((d.days*24) + (d.seconds/3600)) >= 4

def secondaryKeyFunc(trip):
    return getMillis(trip["pickupTime"])

sessions = groupByKeyAndSortValues(taxiDone, secondaryKeyFunc, split).cache()

see("sesions",sessions.take(10))
# Out:
# '---- sesions -----'
# [('001C8AAB90AEE49F36FCAA7B4136C81A',
#   [{'dropoffLoc': <shapely.geometry.point.Point object at 0x1103a61d0>,
#     'dropoffTime': datetime.datetime(2013, 1, 13, 2, 32),
#     'pickupLoc': <shapely.geometry.point.Point object at 0x1103a6160>,
#     'pickupTime': datetime.datetime(2013, 1, 13, 2, 22)},
#    {'dropoffLoc': <shapely.geometry.point.Point object at 0x1103a62b0>,
#     'dropoffTime': datetime.datetime(2013, 1, 13, 4, 41),
#     'pickupLoc': <shapely.geometry.point.Point object at 0x1103a6240>,
#     'pickupTime': datetime.datetime(2013, 1, 13, 4, 19)},
#    {'dropoffLoc': <shapely.geometry.point.Point object at 0x1103a6390>,
#     'dropoffTime': datetime.datetime(2013, 1, 13, 6, 30),
#     'pickupLoc': <shapely.geometry.point.Point object at 0x1103a6320>,
#     'pickupTime': datetime.datetime(2013, 1, 13, 6, 20)},
#    {'dropoffLoc': <shapely.geometry.point.Point object at 0x1103a6470>,
#     'dropoffTime': datetime.datetime(2013, 1, 13, 6, 44),
#     'pickupLoc': <shapely.geometry.point.Point object at 0x1103a6400>,
#     'pickupTime': datetime.datetime(2013, 1, 13, 6, 40)}]),
#  ('0025133AD810DBE80D35FCA8BF0BCA1F',
#   [{'dropoffLoc': <shapely.geometry.point.Point object at 0x1103a62e8>,
#     'dropoffTime': datetime.datetime(2013, 1, 13, 2, 46),
#     'pickupLoc': <shapely.geometry.point.Point object at 0x1103a60f0>,
#     'pickupTime': datetime.datetime(2013, 1, 13, 2, 37)},
#    {'dropoffLoc': <shapely.geometry.point.Point object at 0x1103a64a8>,
#     'dropoffTime': datetime.datetime(2013, 1, 13, 3, 41),
#     'pickupLoc': <shapely.geometry.point.Point object at 0x1103a63c8>,
#     'pickupTime': datetime.datetime(2013, 1, 13, 3, 26)}]),
#  ('00374328FBA75FBFCA7522671250F573',
#   [{'dropoffLoc': <shapely.geometry.point.Point object at 0x1103a6588>,
#     'dropoffTime': datetime.datetime(2013, 1, 13, 4, 3),
#     'pickupLoc': <shapely.geometry.point.Point object at 0x1103a6518>,
#     'pickupTime': datetime.datetime(2013, 1, 13, 3, 47)}]),
#  ('00447A6197DBB329FBF764139ACA6EC4',
#   [{'dropoffLoc': <shapely.geometry.point.Point object at 0x1103a6128>,
#     'dropoffTime': datetime.datetime(2013, 1, 13, 12, 59),
#     'pickupLoc': <shapely.geometry.point.Point object at 0x1103a6208>,
#     'pickupTime': datetime.datetime(2013, 1, 13, 12, 44)},
#    {'dropoffLoc': <shapely.geometry.point.Point object at 0x1103a65f8>,
#     'dropoffTime': datetime.datetime(2013, 1, 13, 14, 24),
#     'pickupLoc': <shapely.geometry.point.Point object at 0x1103a65c0>,
#     'pickupTime': datetime.datetime(2013, 1, 13, 13, 48)},
#    {'dropoffLoc': <shapely.geometry.point.Point object at 0x1103a66d8>,
#     'dropoffTime': datetime.datetime(2013, 1, 13, 16, 20),
#     'pickupLoc': <shapely.geometry.point.Point object at 0x1103a6668>,
#     'pickupTime': datetime.datetime(2013, 1, 13, 15, 55)},
#    {'dropoffLoc': <shapely.geometry.point.Point object at 0x1103a67b8>,
#     'dropoffTime': datetime.datetime(2013, 1, 13, 17, 55),
#     'pickupLoc': <shapely.geometry.point.Point object at 0x1103a6748>,
#     'pickupTime': datetime.datetime(2013, 1, 13, 17, 40)},
#    {'dropoffLoc': <shapely.geometry.point.Point object at 0x1103a6898>,
#     'dropoffTime': datetime.datetime(2013, 1, 13, 18, 15),
#     'pickupLoc': <shapely.geometry.point.Point object at 0x1103a6828>,
#     'pickupTime': datetime.datetime(2013, 1, 13, 17, 59)}]),
#  ('00567B1CBFD51DDFAC73359B09238922',
#   [{'dropoffLoc': <shapely.geometry.point.Point object at 0x1103a6978>,
#     'dropoffTime': datetime.datetime(2013, 1, 13, 9, 37),
#     'pickupLoc': <shapely.geometry.point.Point object at 0x1103a6908>,
#     'pickupTime': datetime.datetime(2013, 1, 13, 9, 34)},
#    {'dropoffLoc': <shapely.geometry.point.Point object at 0x1103a6a58>,
#     'dropoffTime': datetime.datetime(2013, 1, 13, 9, 50),
#     'pickupLoc': <shapely.geometry.point.Point object at 0x1103a69e8>,
#     'pickupTime': datetime.datetime(2013, 1, 13, 9, 48)},
#    {'dropoffLoc': <shapely.geometry.point.Point object at 0x1103a6b38>,
#     'dropoffTime': datetime.datetime(2013, 1, 13, 10, 26),
#     'pickupLoc': <shapely.geometry.point.Point object at 0x1103a6ac8>,
#     'pickupTime': datetime.datetime(2013, 1, 13, 10, 20)},
#    {'dropoffLoc': <shapely.geometry.point.Point object at 0x1103a6c18>,
#     'dropoffTime': datetime.datetime(2013, 1, 13, 10, 41),
#     'pickupLoc': <shapely.geometry.point.Point object at 0x1103a6ba8>,
#     'pickupTime': datetime.datetime(2013, 1, 13, 10, 38)},
#    {'dropoffLoc': <shapely.geometry.point.Point object at 0x1103a6cf8>,
#     'dropoffTime': datetime.datetime(2013, 1, 13, 10, 48),
#     'pickupLoc': <shapely.geometry.point.Point object at 0x1103a6c88>,
#     'pickupTime': datetime.datetime(2013, 1, 13, 10, 45)},
#    {'dropoffLoc': <shapely.geometry.point.Point object at 0x1103a6dd8>,
#     'dropoffTime': datetime.datetime(2013, 1, 13, 10, 57),
#     'pickupLoc': <shapely.geometry.point.Point object at 0x1103a6d68>,
#     'pickupTime': datetime.datetime(2013, 1, 13, 10, 56)},
#    {'dropoffLoc': <shapely.geometry.point.Point object at 0x1103a6eb8>,
#     'dropoffTime': datetime.datetime(2013, 1, 13, 11, 16),
#     'pickupLoc': <shapely.geometry.point.Point object at 0x1103a6e48>,
#     'pickupTime': datetime.datetime(2013, 1, 13, 11, 0)},
#    {'dropoffLoc': <shapely.geometry.point.Point object at 0x1103a6f98>,
#     'dropoffTime': datetime.datetime(2013, 1, 13, 11, 47),
#     'pickupLoc': <shapely.geometry.point.Point object at 0x1103a6f28>,
#     'pickupTime': datetime.datetime(2013, 1, 13, 11, 43)},
#    {'dropoffLoc': <shapely.geometry.point.Point object at 0x1103b30b8>,
#     'dropoffTime': datetime.datetime(2013, 1, 13, 12, 1),
#     'pickupLoc': <shapely.geometry.point.Point object at 0x1103b3048>,
#     'pickupTime': datetime.datetime(2013, 1, 13, 11, 48)},
#    {'dropoffLoc': <shapely.geometry.point.Point object at 0x1103b3198>,
#     'dropoffTime': datetime.datetime(2013, 1, 13, 12, 27),
#     'pickupLoc': <shapely.geometry.point.Point object at 0x1103b3128>,
#     'pickupTime': datetime.datetime(2013, 1, 13, 12, 24)},
#    {'dropoffLoc': <shapely.geometry.point.Point object at 0x1103b3278>,
#     'dropoffTime': datetime.datetime(2013, 1, 13, 12, 36),
#     'pickupLoc': <shapely.geometry.point.Point object at 0x1103b3208>,
#     'pickupTime': datetime.datetime(2013, 1, 13, 12, 28)},
#    {'dropoffLoc': <shapely.geometry.point.Point object at 0x1103b3358>,
#     'dropoffTime': datetime.datetime(2013, 1, 13, 12, 43),
#     'pickupLoc': <shapely.geometry.point.Point object at 0x1103b32e8>,
#     'pickupTime': datetime.datetime(2013, 1, 13, 12, 39)},
#    {'dropoffLoc': <shapely.geometry.point.Point object at 0x1103b3438>,
#     'dropoffTime': datetime.datetime(2013, 1, 13, 12, 51),
#     'pickupLoc': <shapely.geometry.point.Point object at 0x1103b33c8>,
#     'pickupTime': datetime.datetime(2013, 1, 13, 12, 44)},
#    {'dropoffLoc': <shapely.geometry.point.Point object at 0x1103b3518>,
#     'dropoffTime': datetime.datetime(2013, 1, 13, 13, 10),
#     'pickupLoc': <shapely.geometry.point.Point object at 0x1103b34a8>,
#     'pickupTime': datetime.datetime(2013, 1, 13, 12, 59)},
#    {'dropoffLoc': <shapely.geometry.point.Point object at 0x1103b35f8>,
#     'dropoffTime': datetime.datetime(2013, 1, 13, 13, 18),
#     'pickupLoc': <shapely.geometry.point.Point object at 0x1103b
#              '33BC9D03BE4E9B8E1E8965815DEAE347': 1,
#              '33BEB840660FC5436EEAE1BA3F5A1A38': 1,
#              '33CF9C38C8EE2286F6D280005C9313C3': 1,
#              '33E4EF05DC722D4EA92451181C8C8106': 1,
#              ...})

# %%
# def flatmap(f, items):
#     return chain.from_iterable(imap(f, items))

def sliding(num, l):
    return [l[i:i + num] for i in range(len(l) - (num-1))]

def boroughDuration(t1, t2):
    b = borough(t1)
    d = t2["pickupTime"] - t1["dropoffTime"]
    return (b, d)

def mapper(trips):
    iter = sliding(2, trips)
    viter = filter(lambda x: len(x) == 2, iter)
    return map(lambda p: boroughDuration(p[0], p[1]), viter)

boroughDurations = sessions.values().flatMap(mapper).cache()

boroughDurationsCount = boroughDurations.values().map(lambda d: int((d.days*24) + (d.seconds/3600))).countByValue().items()

sortedBoroughDurationsCount = sorted(boroughDurationsCount, key=itemgetter(1), reverse=True)

for val in sortedBoroughDurationsCount:
    print(val)

taxiDone.unpersist()
# Out:
# (0, 80875)
# (1, 4566)
# (2, 984)
# (3, 200)
# PythonRDD[18] at RDD at PythonRDD.scala:48

# %%
def stats(d):
    s = StatCounter()
    return s.merge(((d.days*24*3600) + d.seconds))

boroughCollected = boroughDurations\
    .filter(lambda x: ((x[1].days*24*3600) + x[1].seconds) >= 0)\
    .mapValues(stats)\
    .reduceByKey(lambda a, b: a.mergeStats(b))\
    .collect()

for val in boroughCollected:
    print(val)

boroughDurations.unpersist()
# Out:
# ('Manhattan', (count: 79209, mean: 901.9571260841541, stdev: 1406.68763878, max: 14040.0, min: 0.0))
# ('Brooklyn', (count: 2592, mean: 2058.6458333333353, stdev: 2137.4312626, max: 12540.0, min: 0.0))
# (None, (count: 358, mean: 2365.3072625698323, stdev: 2121.50357519, max: 12900.0, min: 0.0))
# ('Queens', (count: 4132, mean: 2641.884559535333, stdev: 2238.15972011, max: 13260.0, min: 0.0))
# ('Bronx', (count: 301, mean: 2196.4784053156145, stdev: 2009.55513755, max: 11280.0, min: 60.0))
# ('Staten Island', (count: 7, mean: 3531.4285714285716, stdev: 2020.60407213, max: 6300.0, min: 660.0))
# PythonRDD[60] at RDD at PythonRDD.scala:48

# %%
rdd = sc.parallelize([("b", (2,3)), ("a", (1,2)), ("a", (2,7)), ("b", (4,2))],3)
rdd2 = rdd.map(lambda x: ((x[0], x[1][0]), x[1]))
rdd2.collect()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-91bd1af97929> in <module>()
# ----> 1 rdd = sc.parallelize([("b", (2,3)), ("a", (1,2)), ("a", (2,7)), ("b", (4,2))],3)
#       2 rdd2 = rdd.map(lambda x: ((x[0], x[1][0]), x[1]))
#       3 rdd2.collect()
#       4
#
# NameError: name 'sc' is not defined

# %%
rdd3 = rdd2.sortByKey()
rdd3.collect()
# Out:
# [(('a', 1), (1, 2)),
#  (('a', 2), (2, 7)),
#  (('b', 2), (2, 3)),
#  (('b', 4), (4, 2))]

# %%
# Out:
# [(('b', 2), (2, 3)),
#  (('b', 4), (4, 2)),
#  (('a', 1), (1, 2)),
#  (('a', 2), (2, 7))]
